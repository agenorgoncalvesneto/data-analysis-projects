# %%
import pandas as pd
import sqlite3

from nba_api.stats.endpoints import leaguegamefinder
from nba_api.stats.static import teams

# %%
with sqlite3.connect('data/games.db') as con:
    games = pd.read_sql(sql='SELECT * FROM games', con=con)

games
# Out:
#         game_id event  season              date    status  \
# 0      vDxeS9an   NBA    1993  04.11.1993 22:00  Finished
# 1      SxZjTkpt   NBA    1993  04.11.1993 22:00  Finished
# 2      SbWrLhhJ   NBA    1993  04.11.1993 22:00  Finished
# 3      l8XvMYxD   NBA    1993  04.11.1993 22:00  Finished
# 4      KYSzNEN6   NBA    1993  04.11.1993 22:00  Finished
# ...         ...   ...     ...               ...       ...
# 36526  d03RaCUh   NBA    2021  20.11.2021 21:30  Finished
# 36527  nkdvcAEB   NBA    2021  20.11.2021 22:00  Finished
# 36528  UD1Zcja5   NBA    2021  20.11.2021 22:00  Finished
# 36529  IyJBv2bp   NBA    2021  21.11.2021 00:00  Finished
# 36530  QuerdUTH   NBA    2021  21.11.2021 00:00  Finished
#
#                      home_team               away_team  home_score  \
# 0                   Utah Jazz        Dallas Mavericks          102
# 1           San Antonio Spurs   Golden State Warriors           91
# ...

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36531 entries, 0 to 36530
# Data columns (total 37 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   game_id     36531 non-null  object
#  1   event       36531 non-null  object
#  2   season      36531 non-null  int64
#  3   date        36531 non-null  object
#  4   status      36531 non-null  object
#  5   home_team   36531 non-null  object
#  6   away_team   36531 non-null  object
#  7   home_score  36531 non-null  int64
#  8   away_score  36531 non-null  int64
#  9   home_2PA    12636 non-null  float64
#  10  away_2PA    12636 non-null  float64
#  11  home_2PM    12636 non-null  float64
#  12  away_2PM    12636 non-null  float64
#  13  home_3PA    12636 non-null  float64
#  14  away_3PA    12636 non-null  float64
#  15  home_3PM    12636 non-null  float64
#  16  away_3PM    12636 non-null  float64
#  17  home_FTA    12636 non-null  float64
# ...

# %%
games['date'] = pd.to_datetime(games['date'])

# %%
games.sort_values('date', ascending=False).head(10)
games['date'].
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-ea46a8437306> in <module>
#       1 games.sort_values('date', ascending=False).head(10)
# ----> 2 games['date'].day
#
# ~/Documents/data-analysis-projects/venv/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'day'

# %%
games['home_FGA'] == games['home_2PA'] + games['home_3PA']
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1238    True
# 1239    True
# 1240    True
# 1241    True
# 1242    True
# Length: 36531, dtype: bool

# %%
teams[0]
# Out:
# {'id': 1610612737,
#  'full_name': 'Atlanta Hawks',
#  'abbreviation': 'ATL',
#  'nickname': 'Hawks',
#  'city': 'Atlanta',
#  'state': 'Atlanta',
#  'year_founded': 1949}

# %%
lakers = [team for team in teams if team['full_name'] == 'Los Angeles Lakers']
lakers_id = lakers[0]['id']
lakers
# Out:
# [{'id': 1610612747,
#   'full_name': 'Los Angeles Lakers',
#   'abbreviation': 'LAL',
#   'nickname': 'Lakers',
#   'city': 'Los Angeles',
#   'state': 'California',
#   'year_founded': 1948}]

# %%
gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=1610612747)

# %%
games = gamefinder.get_data_frames()[0]
games
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION           TEAM_NAME     GAME_ID  \
# 0        22021  1610612747               LAL  Los Angeles Lakers  0022100264
# 1        22021  1610612747               LAL  Los Angeles Lakers  0022100249
# 2        22021  1610612747               LAL  Los Angeles Lakers  0022100232
# 3        22021  1610612747               LAL  Los Angeles Lakers  0022100219
# 4        22021  1610612747               LAL  Los Angeles Lakers  0022100209
# ...        ...         ...               ...                 ...         ...
# 3677     21983  1610612747               LAL  Los Angeles Lakers  0028300066
# 3678     21983  1610612747               LAL  Los Angeles Lakers  0028300053
# 3679     21983  1610612747               LAL  Los Angeles Lakers  0028300035
# 3680     21983  1610612747               LAL  Los Angeles Lakers  0028300010
# 3681     21983  1610612747               LAL  Los Angeles Lakers  0028300002
#
# ...

# %%
games.dtypes.to_dict()
# Out:
# {'SEASON_ID': dtype('O'),
#  'TEAM_ID': dtype('int64'),
#  'TEAM_ABBREVIATION': dtype('O'),
#  'TEAM_NAME': dtype('O'),
#  'GAME_ID': dtype('O'),
#  'GAME_DATE': dtype('O'),
#  'MATCHUP': dtype('O'),
#  'WL': dtype('O'),
#  'MIN': dtype('int64'),
#  'PTS': dtype('int64'),
#  'FGM': dtype('int64'),
#  'FGA': dtype('int64'),
#  'FG_PCT': dtype('float64'),
#  'FG3M': dtype('int64'),
#  'FG3A': dtype('int64'),
#  'FG3_PCT': dtype('float64'),
#  'FTM': dtype('int64'),
#  'FTA': dtype('int64'),
#  'FT_PCT': dtype('float64'),
#  'OREB': dtype('int64'),
#  'DREB': dtype('int64'),
#  'REB': dtype('int64'),
#  'AST': dtype('int64'),
#  'STL': dtype('int64'),
#  'BLK': dtype('int64'),
#  'TOV': dtype('int64'),
#  'PF': dtype('int64'),
#  'PLUS_MINUS': dtype('float64')}

# %%
games.columns.to_list()
# Out:
# ['SEASON_ID',
#  'TEAM_ID',
#  'TEAM_ABBREVIATION',
#  'TEAM_NAME',
#  'GAME_ID',
#  'GAME_DATE',
#  'MATCHUP',
#  'WL',
#  'MIN',
#  'PTS',
#  'FGM',
#  'FGA',
#  'FG_PCT',
#  'FG3M',
#  'FG3A',
#  'FG3_PCT',
#  'FTM',
#  'FTA',
#  'FT_PCT',
#  'OREB',
#  'DREB',
#  'REB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PLUS_MINUS']

# %%
games.head(1).to_dict()
# Out:
# {'SEASON_ID': {0: '22021'},
#  'TEAM_ID': {0: 1610612747},
#  'TEAM_ABBREVIATION': {0: 'LAL'},
#  'TEAM_NAME': {0: 'Los Angeles Lakers'},
#  'GAME_ID': {0: '0022100264'},
#  'GAME_DATE': {0: '2021-11-23'},
#  'MATCHUP': {0: 'LAL @ NYK'},
#  'WL': {0: 'L'},
#  'MIN': {0: 241},
#  'PTS': {0: 100},
#  'FGM': {0: 34},
#  'FGA': {0: 91},
#  'FG_PCT': {0: 0.374},
#  'FG3M': {0: 11},
#  'FG3A': {0: 36},
#  'FG3_PCT': {0: 0.306},
#  'FTM': {0: 21},
#  'FTA': {0: 30},
#  'FT_PCT': {0: 0.7},
#  'OREB': {0: 13},
#  'DREB': {0: 37},
#  'REB': {0: 50},
#  'AST': {0: 23},
#  'STL': {0: 8},
#  'BLK': {0: 3},
#  'TOV': {0: 12},
#  'PF': {0: 17},
#  'PLUS_MINUS': {0: -6.0}}

# %%
sorted(games['SEASON_ID'].unique(), reverse=True)
# Out:
# ['52020',
#  '42020',
#  '42019',
#  '42012',
#  '42011',
#  '42010',
#  '42009',
#  '42008',
#  '42007',
#  '42006',
#  '42005',
#  '42003',
#  '42002',
#  '42001',
#  '42000',
#  '41999',
#  '41998',
#  '41997',
#  '41996',
#  '41995',
#  '41994',
#  '41992',
#  '41991',
#  '41990',
#  '41989',
#  '41988',
#  '41987',
#  '41986',
#  '41985',
#  '41984',
#  '41983',
#  '22021',
#  '22020',
#  '22019',
#  '22018',
#  '22017',
#  '22016',
#  '22015',
#  '22014',
#  '22013',
#  '22012',
#  '22011',
#  '22010',
#  '22009',
#  '22008',
#  '22007',
#  '22006',
#  '22005',
#  '22004',
#  '22003',
#  '22002',
#  '22001',
#  '22000',
#  '21999',
#  '21998',
#  '21997',
#  '21996',
#  '21995',
#  '21994',
#  '21993',
#  '21992',
#  '21991',
#  '21990',
#  '21989',
#  '21988',
#  '21987',
#  '21986',
#  '21985',
#  '21984',
#  '21983',
#  '12021',
#  '12020',
#  '12019',
#  '12018',
#  '12017',
#  '12016',
#  '12015',
#  '12014',
#  '12013',
#  '12012',
#  '12011',
#  '12010',
#  '12009',
# ...

# %%
games[games.SEASON_ID == '22018'].tail(15)
# Out:
#     SEASON_ID     TEAM_ID TEAM_ABBREVIATION           TEAM_NAME     GAME_ID  \
# 297     22018  1610612747               LAL  Los Angeles Lakers  0021800066
# 298     22018  1610612747               LAL  Los Angeles Lakers  0021800060
# 299     22018  1610612747               LAL  Los Angeles Lakers  0021800048
# 300     22018  1610612747               LAL  Los Angeles Lakers  0021800035
# 301     22018  1610612747               LAL  Los Angeles Lakers  0021800016
# 308     22018  1610612747               LAL  Los Angeles Lakers  1521800082
# 309     22018  1610612747               LAL  Los Angeles Lakers  1521800080
# 310     22018  1610612747               LAL  Los Angeles Lakers  1521800076
# 311     22018  1610612747               LAL  Los Angeles Lakers  1521800059
# 312     22018  1610612747               LAL  Los Angeles Lakers  1521800045
# 313     22018  1610612747               LAL  Los Angeles Lakers  1521800030
# ...

# %%
games[games.SEASON_ID == '12018']
# Out:
#     SEASON_ID     TEAM_ID TEAM_ABBREVIATION           TEAM_NAME     GAME_ID  \
# 302     12018  1610612747               LAL  Los Angeles Lakers  0011800079
# 303     12018  1610612747               LAL  Los Angeles Lakers  0011800065
# 304     12018  1610612747               LAL  Los Angeles Lakers  0011800042
# 305     12018  1610612747               LAL  Los Angeles Lakers  0011800027
# 306     12018  1610612747               LAL  Los Angeles Lakers  0011800020
# 307     12018  1610612747               LAL  Los Angeles Lakers  0011800010
#
#       GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 302  2018-10-12    LAL @ GSW  W  241  119  ...   0.732     9    41   50   29
# 303  2018-10-10  LAL vs. GSW  W  239  123  ...   0.826     9    36   45   28
# 304  2018-10-06  LAL vs. LAC  L  240   87  ...   0.636    11    37   48   24
# 305  2018-10-04  LAL vs. SAC  W  240  128  ...   0.727     7    41   48   19
# ...

# %%
games[games.SEASON_ID == '22018']
# Out:
#     SEASON_ID     TEAM_ID TEAM_ABBREVIATION           TEAM_NAME     GAME_ID  \
# 220     22018  1610612747               LAL  Los Angeles Lakers  0021801219
# 221     22018  1610612747               LAL  Los Angeles Lakers  0021801208
# 222     22018  1610612747               LAL  Los Angeles Lakers  0021801192
# 223     22018  1610612747               LAL  Los Angeles Lakers  0021801179
# 224     22018  1610612747               LAL  Los Angeles Lakers  0021801161
# ..        ...         ...               ...                 ...         ...
# 313     22018  1610612747               LAL  Los Angeles Lakers  1521800030
# 314     22018  1610612747               LAL  Los Angeles Lakers  1521800020
# 315     22018  1610612747               LAL  Los Angeles Lakers  1321800005
# 316     22018  1610612747               LAL  Los Angeles Lakers  1321800003
# 317     22018  1610612747               LAL  Los Angeles Lakers  1321800002
#
# ...

# %%
games[games.GAME_ID == '1521800082'].to_dict()
# Out:
# {'SEASON_ID': {308: '22018'},
#  'TEAM_ID': {308: 1610612747},
#  'TEAM_ABBREVIATION': {308: 'LAL'},
#  'TEAM_NAME': {308: 'Los Angeles Lakers'},
#  'GAME_ID': {308: '1521800082'},
#  'GAME_DATE': {308: '2018-07-17'},
#  'MATCHUP': {308: 'LAL vs. POR'},
#  'WL': {308: 'L'},
#  'MIN': {308: 199},
#  'PTS': {308: 73},
#  'FGM': {308: 27},
#  'FGA': {308: 69},
#  'FG_PCT': {308: 0.391},
#  'FG3M': {308: 3},
#  'FG3A': {308: 21},
#  'FG3_PCT': {308: 0.143},
#  'FTM': {308: 16},
#  'FTA': {308: 21},
#  'FT_PCT': {308: 0.762},
#  'OREB': {308: 4},
#  'DREB': {308: 27},
#  'REB': {308: 31},
#  'AST': {308: 11},
#  'STL': {308: 5},
#  'BLK': {308: 1},
#  'TOV': {308: 15},
#  'PF': {308: 25},
#  'PLUS_MINUS': {308: -18.2}}
